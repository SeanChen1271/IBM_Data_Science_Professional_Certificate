# %% [markdown]
# ## 4. Neighbourhood Crime Data <a name='crime_data'></a>

# %%
# Data Source: Toronto Police Service - Public Safety Data Portal - Neighbourhood Crime Rates (Boundary File)
import pandas as pd

df_crime = pd.read_csv('Neighbourhood_Crime_Rates_(Boundary_File)_.csv')
df_crime.head()
# Out:
#    OBJECTID            Neighbourhood  Hood_ID  Population  Assault_2014  \
# 0         1           Yonge-St.Clair       97       12528            20
# 1         2  York University Heights       27       27593           271
# 2         3         Lansing-Westgate       38       16164            44
# 3         4       Yorkdale-Glen Park       31       14804           106
# 4         5      Stonegate-Queensway       16       25051            88
#
#    Assault_2015  Assault_2016  Assault_2017  Assault_2018  Assault_2019  ...  \
# 0            29            39            27            34            37  ...
# 1           296           361           344           357           370  ...
# 2            80            68            85            75            72  ...
# 3           136           174           161           175           209  ...
# 4            71            76            95            87            82  ...
#
#    TheftOver_2015  TheftOver_2016  TheftOver_2017  TheftOver_2018  \
# ...

# %%
# ignore ssl certificate errors
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from geopy.geocoders import Nominatim

address = 'Lawrence Park, Toronto' # spatial centre of Toronto

geolocator = Nominatim(user_agent='toronto_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the City of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the City of Toronto are 43.729199, -79.4032525.

# %%
import folium

# Data Source: Toronto Open Data Portal - Neighbourhoods - Geojson
geo_toronto = r'Neighbourhoods.geojson'

# create a plain toronto map
map_toronto_crime = folium.Map(location=[latitude, longitude], zoom_start=11)
map_toronto_crime
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_toronto_crime.choropleth(geo_data=geo_toronto,
                             data=df_crime,
                             columns=['Hood_ID', 'TheftOver_Rate_2019'],
                             key_on='feature.properties.AREA_SHORT_CODE',
                             fill_color='YlOrRd',
                             fill_opacity=0.4,
                             line_opacity=0.3,
                             legend_name='TheftOver_Rate_2019')
map_toronto_crime
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/folium/folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_crime.shape
# Out:
# (140, 60)

# %%
neighbourhood_data = pd.read_csv('neighbourhood-profiles-2016-csv.csv')

# %%
neighbourhood_data.head()
# Out:
#    _id                   Category                      Topic  \
# 0    1  Neighbourhood Information  Neighbourhood Information
# 1    2  Neighbourhood Information  Neighbourhood Information
# 2    3                 Population   Population and dwellings
# 3    4                 Population   Population and dwellings
# 4    5                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# ...

# %%
neighbourhood_list = neighbourhood_data.columns.tolist()[6:146]
neighbourhood_list
# Out:
# ['Agincourt North',
#  'Agincourt South-Malvern West',
#  'Alderwood',
#  'Annex',
#  'Banbury-Don Mills',
#  'Bathurst Manor',
#  'Bay Street Corridor',
#  'Bayview Village',
#  'Bayview Woods-Steeles',
#  'Bedford Park-Nortown',
#  'Beechborough-Greenbrook',
#  'Bendale',
#  'Birchcliffe-Cliffside',
#  'Black Creek',
#  'Blake-Jones',
#  'Briar Hill-Belgravia',
#  'Bridle Path-Sunnybrook-York Mills',
#  'Broadview North',
#  'Brookhaven-Amesbury',
#  'Cabbagetown-South St. James Town',
#  'Caledonia-Fairbank',
#  'Casa Loma',
#  'Centennial Scarborough',
#  'Church-Yonge Corridor',
#  'Clairlea-Birchmount',
#  'Clanton Park',
#  'Cliffcrest',
#  'Corso Italia-Davenport',
#  'Danforth',
#  'Danforth East York',
#  'Don Valley Village',
#  'Dorset Park',
#  'Dovercourt-Wallace Emerson-Junction',
#  'Downsview-Roding-CFB',
#  'Dufferin Grove',
#  'East End-Danforth',
#  'Edenbridge-Humber Valley',
#  'Eglinton East',
#  'Elms-Old Rexdale',
#  'Englemount-Lawrence',
# ...

# %%
len(neighbourhood_list)
# Out:
# 140

# %%
# ignore ssl certificate errors
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from geopy.geocoders import Nominatim

for neighbourhood in neighbourhood_list :
    
    address = '{}, Ontario'.format(neighbourhood)
    
    try :
        geolocator = Nominatim(user_agent='toronto_explorer')
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of the {} are {}, {}.'.format(neighbourhood, latitude, longitude))
    except :
        print('Error for {}'.format(neighbourhood))
# Out:
# The geograpical coordinate of the Agincourt North are 43.8080383, -79.2664391.
# The geograpical coordinate of the Agincourt South-Malvern West are 43.8033965, -79.25756324844703.
# The geograpical coordinate of the Alderwood are 43.6017173, -79.5452325.
# The geograpical coordinate of the Annex are 43.6703377, -79.407117.
# The geograpical coordinate of the Banbury-Don Mills are 43.7348039, -79.3572426.
# The geograpical coordinate of the Bathurst Manor are 43.76389295, -79.45636693710946.
# The geograpical coordinate of the Bay Street Corridor are 43.6673421, -79.3884571.
# The geograpical coordinate of the Bayview Village are 43.7691966, -79.3766617.
# The geograpical coordinate of the Bayview Woods-Steeles are 43.7981268, -79.3829726.
# Error for Bedford Park-Nortown
# Error for Beechborough-Greenbrook
# The geograpical coordinate of the Bendale are 43.7535196, -79.2553355.
# Error for Birchcliffe-Cliffside
# ...
